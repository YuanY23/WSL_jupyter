# %% [markdown]
# ## 练习 1：编写一个加法函数
# 请编写一个函数 `add(a, b)`，返回 a 和 b 的和。

# %%
def add(a, b):
    ### BEGIN SOLUTION
    return a + b
    ### END SOLUTION

# %%
# 公开测试（学生能看见，用来自己检查）
assert add(1, 2) == 3
assert add(-1, 1) == 0

### BEGIN HIDDEN TESTS
# 隐藏测试（学生看不见，用于最终防止作弊的评分）
assert add(0, 0) == 0
assert add(100, 200) == 300
### END HIDDEN TESTS
